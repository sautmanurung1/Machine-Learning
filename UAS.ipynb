# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('Rice-Gonen and Jasmine.csv')
dataset
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0          1  4537        92.229316        64.012769      0.719916
# 1          2  2872        74.691881        51.400454      0.725553
# 2          3  3048        76.293164        52.043491      0.731211
# 3          4  3073        77.033628        51.928487      0.738639
# 4          5  3693        85.124785        56.374021      0.749282
# ...      ...   ...              ...              ...           ...
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  \
# 0            4677      76.004525  0.657536    273.085   0.764510
# ...

# %%
data = np.asarray(dataset[['MajorAxisLength','MinorAxisLength']])
print(data)
# Out:
# [[ 92.2293165   64.01276874]
#  [ 74.69188071  51.40045446]
#  [ 76.2931638   52.04349114]
#  ...
#  [154.7770845   52.90808455]
#  [151.3979239   51.47459975]
#  [153.0819809   51.59060559]]

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# %%
plt.title("Dendogram")
Dendrogram = sch.dendrogram(sch.linkage(data, method = 'ward'))

# %%
plt.title("Dendogram")
Dendrogram = sch.dendrogram(sch.linkage(data, method = 'average'))

# %%
plt.title("Dendogram")
Dendrogram = sch.dendrogram(sch.linkage(data, method = 'complete'))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac = AgglomerativeClustering(n_clusters=5)
output = ac.fit_predict(data)

plt.scatter(data[:,0], data[:,1], s=50, c=output, cmap='rainbow')
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=5, affinity='manhattan', linkage='average')
output = ac.fit_predict(data)

plt.scatter(data[:,0], data[:,1], s=50, c=output, cmap='rainbow')
plt.show()
